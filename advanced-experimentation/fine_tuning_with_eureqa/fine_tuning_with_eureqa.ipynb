# %% [markdown]
# # Fine-tuning Models with the Eureqa Algorithm

# %% [markdown]
# [Eureqa](https://docs.datarobot.com/en/docs/modeling/analyze-models/describe/eureqa.html) is a symbolic regression algorithm that searches the space of mathematical expressions to find the best fit for a given dataset, while minimizing both error and complexity. Eureqa came out of Cornell's AI Lab in 2009, developed into a company called Nutonian, and then was acquired by DataRobot in 2017. Eureqa now lives as a blueprint within DataRobot.
#
# ## Why use Eureqa?
#
# 1. Eureqa returns human-readable and interpretable analytic expressions, which are easily reviewed by subject matter experts.
#
# 2. Eureqa is very good at feature selection because the algorithm is forced to reduce complexity during the model building process. For example, if the data had 20 different columns used to predict the target variable, the search for a simple expression would result in an expression that only uses the strongest predictors.
#
# 3. Eureqa works well with small datasets, so it's very popular with scientific researchers who gather data from physical experiments that don’t produce massive amounts of data.
#
# 4. Eureqa provides an easy way to incorporate domain knowledge. If you know the underlying relationship in the system that you're modeling, you can give Eureqa a "hint," (for example, the formula for heat transfer or how house prices work in a particular neighborhood) as a building block or a starting point to learn from. Eureqa will build machine learning corrections from there.

# %% [markdown]
# # Background

# %% [markdown]
# In classical Newtonian mechanics, it is possible to derive that the behavior (position, velocity, and acceleration) of a [double pendulum](https://en.wikipedia.org/wiki/Double_pendulum) is exactly modeled by the following equation:
#
# a2 = v1<sup>2</sup> * sin(x1 - x2) - a1 * cos(x2 - x1) - g * sin(x2)
#
# Where g is the gravitational constant – approximately 9.81 or 9.82 m/s<sup>2</sup> on the surface of the Earth, depending on your latitude, longitude, and altitude. We also assume that the two pendulums are both of unit length; otherwise additional length coefficients are involved.
#
# Let's use DataRobot to try and predict the acceleration of the second pendulum (a2).

# %% [markdown]
# # Setup

# %%
import os
import sys
import time
import warnings

import datarobot as dr
import pandas as pd
import requests

warnings.filterwarnings("ignore")

# wider .head()s
pd.options.display.width = 0
pd.options.display.max_columns = 200
pd.options.display.max_rows = 2000

RANDOM_SEED = 321

# %% [markdown]
# # Import data
#
# Data dictionary:
# * _t_: Timestep (seconds)
# * _x1_: Position (m) of the first pendulum
# * _x2_: Position (m) of the second pendulum
# * _v1_: Velocity (m/s) of the first pendulum
# * _v2_: Velocity (m/s) of the second pendulum
# * _a1_: Acceleration (m/$s^2$) of the first pendulum
# * _a2_: Accerlation (m/$s^2$) of the second pendulum

# %%
df = pd.read_csv(
    "https://s3.amazonaws.com/datarobot_public_datasets/double-pendulum.csv"
)
df.head()
# Out:
#           t    x1    x2      v1       v2    a1    a2
# 0  0.000000  2.36  3.14 -0.0100 -0.01000 -9.24  6.53
# 1  0.000862  2.36  3.14 -0.0180 -0.00437 -9.24  6.53
# 2  0.001720  2.36  3.14 -0.0259  0.00126 -9.24  6.53
# 3  0.002590  2.36  3.14 -0.0339  0.00689 -9.24  6.53
# 4  0.003450  2.36  3.14 -0.0418  0.01250 -9.24  6.53

# %%
len(df)
# Out:
# 2429

# %% [markdown]
# # Connect to DataRobot
#
# Read more about different options for [connecting to DataRobot from the client](https://docs.datarobot.com/en/docs/api/api-quickstart/api-qs.html).

# %%
# The URL may vary depending on your hosting preference, this example is for DataRobot Managed AI Cloud
DATAROBOT_ENDPOINT = "https://app.datarobot.com/api/v2"

# The API Token can be found by clicking the avatar icon and then </> Developer Tools
DATAROBOT_API_TOKEN = "<INSERT YOUR DataRobot API Token>"

client =dr.Client(
    token=DATAROBOT_API_TOKEN, 
    endpoint=DATAROBOT_ENDPOINT,
    user_agent_suffix='AIA-AE-EUQ-110' #Optional but helps DataRobot improve this workflow
)

dr.client._global_client = client

# %% [markdown]
# # Kick off DataRobot project
#
# We want to predict _a2_, the acceleration of the second pendulum, using the other columns within the dataset as our features.

# %%
project_eureqa = dr.Project.create(
    sourcedata=df,
    project_name="AI_Accelerator_Eureqa_{}".format(
        pd.datetime.now().strftime("%Y-%m-%d %H:%M")
    ),
)

# Set the project's target and set quick mode
project_eureqa.set_target(
    target="a2",
    mode="quick",
    worker_count=-1,
    advanced_options=dr.AdvancedOptions(seed=RANDOM_SEED),
)
# Out:
# Project(AI_Accelerator_Eureqa_2023-02-22 15:49)

# %% [markdown]
# # Add Eureqa blueprints
#
# Once AutoPilot has finished running, we'll add and train a Eureqa blueprint from the Repository.

# %%
# there are many eureqa blueprints available in the repository
# the "Eureqa Regressor" (or "classifier") blueprints are the original Eureqa evolutionary model
# the "Eureqa General Additive Model" blueprints are a 2-stage approach that first fits an xgboost model, then runs Eureqa on the smoothed signal
# the number of generations just denotes how long each blueprint will continue running
for bp in project_eureqa.get_blueprints():
    if bp.model_type.startswith("Eureqa"):
        print(bp.model_type)
# Out:
# Eureqa Regressor (Instant Search: 40 Generations)
# Eureqa Generalized Additive Model (40 Generations)
# Eureqa Generalized Additive Model (1000 Generations)
# Eureqa Generalized Additive Model (10000 Generations)
# Eureqa Regressor (Quick Search: 250 Generations)
# Eureqa Regressor (Default Search: 3000 Generations)

# %%
# we'll run the eureqa 3k gen regressor blueprint from the repository, adding it to the leaderboard
eq_bp = next(
    bp
    for bp in project_eureqa.get_blueprints()
    if bp.model_type == "Eureqa Regressor (Default Search: 3000 Generations)"
)
job_id = project_eureqa.train(eq_bp.id)
eq_model = dr.ModelJob.get(project_eureqa.id, job_id).get_result_when_complete()
job = eq_model.cross_validate()
job.wait_for_completion()
eq_model
# Out:
# Model('Eureqa Regressor (Default Search: 3000 Generations)')

# %%
def view_cv_scores(project, metric="RMSE"):
    """
    View the models with the best validation scores.
    """
    models = project.get_models()
    leaderboard = []
    for m in models:
        leaderboard.append([m.model_type, m.metrics[metric]["crossValidation"]])
    leaderboard_df = pd.DataFrame(leaderboard, columns=["model", "cv_score"]).dropna()
    return leaderboard_df.sort_values(by="cv_score")

# %%
# see where the un-modified eureqa model initially shows up on the leaderboard
project_eureqa.wait_for_autopilot()
view_cv_scores(project_eureqa)
# Out:
# In progress: 16, queued: 0 (waited: 0s)
# In progress: 16, queued: 0 (waited: 1s)
# In progress: 15, queued: 0 (waited: 1s)
# In progress: 15, queued: 0 (waited: 2s)
# In progress: 15, queued: 0 (waited: 3s)
# In progress: 13, queued: 0 (waited: 5s)
# In progress: 10, queued: 0 (waited: 9s)
# In progress: 4, queued: 0 (waited: 15s)
# In progress: 0, queued: 0 (waited: 29s)
# In progress: 0, queued: 0 (waited: 49s)
# In progress: 0, queued: 0 (waited: 69s)
# In progress: 1, queued: 0 (waited: 90s)
# In progress: 1, queued: 0 (waited: 110s)
# In progress: 1, queued: 0 (waited: 130s)
# In progress: 0, queued: 0 (waited: 151s)
# In progress: 0, queued: 0 (waited: 171s)
# In progress: 0, queued: 0 (waited: 192s)
#                                                model   cv_score
# 1  Light Gradient Boosting on ElasticNet Predicti...   1.931188
# 0  Light Gradient Boosting on ElasticNet Predicti...   1.932670
# 2  Light Gradient Boosted Trees Regressor with Ea...   2.173850
# 3           eXtreme Gradient Boosted Trees Regressor   2.251016
# 4                             RandomForest Regressor   2.698264
# 7  Eureqa Regressor (Default Search: 3000 Generat...  14.649408

# %% [markdown]
# # Tune Eureqa

# %% [markdown]
# There are some use cases where Eureqa shows up at the top of the leaderboard just by using default settings, but other cases (including this one) need modifications to fit our domain knowledge to how Eureqa is being run.
#
# In our case, we know that rotation is a key component to predicting the movement of a double pendulum. So we'll modify the Eureqa model to include the sin/cos building blocks.

# %%
# this is how we begin tuning eureqa models - let's look at the available tuning options
tune = eq_model.start_advanced_tuning_session()
tune.get_parameters()["tuning_parameters"]
# Out:
# [{'parameter_name': 'building_block__absolute_value',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fYWJzb2x1dGVfdmFsdWUiLCJ2aWQiOiIyIn0',
#   'default_value': 'Disabled',
#   'current_value': 'Disabled',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__addition',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fYWRkaXRpb24iLCJ2aWQiOiIyIn0',
#   'default_value': 0,
#   'current_value': 0,
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__arccosine',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fYXJjY29zaW5lIiwidmlkIjoiMiJ9',
#   'default_value': 'Disabled',
#   'current_value': 'Disabled',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__arcsine',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fYXJjc2luZSIsInZpZCI6IjIifQ',
#   'default_value': 'Disabled',
#   'current_value': 'Disabled',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__arctangent',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fYXJjdGFuZ2VudCIsInZpZCI6IjIifQ',
#   'default_value': 'Disabled',
#   'current_value': 'Disabled',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__ceiling',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fY2VpbGluZyIsInZpZCI6IjIifQ',
#   'default_value': 'Disabled',
#   'current_value': 'Disabled',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__complementary_error_function',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fY29tcGxlbWVudGFyeV9lcnJvcl9mdW5jdGlvbiIsInZpZCI6IjIifQ',
#   'default_value': 'Disabled',
#   'current_value': 'Disabled',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__constant',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fY29uc3RhbnQiLCJ2aWQiOiIyIn0',
#   'default_value': 0,
#   'current_value': 0,
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__cosine',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fY29zaW5lIiwidmlkIjoiMiJ9',
#   'default_value': 'Disabled',
#   'current_value': 'Disabled',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__division',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fZGl2aXNpb24iLCJ2aWQiOiIyIn0',
#   'default_value': 2,
#   'current_value': 2,
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__equal-to',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fZXF1YWwtdG8iLCJ2aWQiOiIyIn0',
#   'default_value': 'Disabled',
#   'current_value': 'Disabled',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__error_function',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fZXJyb3JfZnVuY3Rpb24iLCJ2aWQiOiIyIn0',
#   'default_value': 'Disabled',
#   'current_value': 'Disabled',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__exponential',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fZXhwb25lbnRpYWwiLCJ2aWQiOiIyIn0',
#   'default_value': 'Disabled',
#   'current_value': 'Disabled',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__factorial',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fZmFjdG9yaWFsIiwidmlkIjoiMiJ9',
#   'default_value': 'Disabled',
#   'current_value': 'Disabled',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__floor',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fZmxvb3IiLCJ2aWQiOiIyIn0',
#   'default_value': 'Disabled',
#   'current_value': 'Disabled',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__gaussian_function',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fZ2F1c3NpYW5fZnVuY3Rpb24iLCJ2aWQiOiIyIn0',
#   'default_value': 'Disabled',
#   'current_value': 'Disabled',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__greater-than',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fZ3JlYXRlci10aGFuIiwidmlkIjoiMiJ9',
#   'default_value': 'Disabled',
#   'current_value': 'Disabled',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__greater-than-or-equal',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fZ3JlYXRlci10aGFuLW9yLWVxdWFsIiwidmlkIjoiMiJ9',
#   'default_value': 'Disabled',
#   'current_value': 'Disabled',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__hyperbolic_cosine',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19faHlwZXJib2xpY19jb3NpbmUiLCJ2aWQiOiIyIn0',
#   'default_value': 'Disabled',
#   'current_value': 'Disabled',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__hyperbolic_sine',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19faHlwZXJib2xpY19zaW5lIiwidmlkIjoiMiJ9',
#   'default_value': 'Disabled',
#   'current_value': 'Disabled',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__hyperbolic_tangent',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19faHlwZXJib2xpY190YW5nZW50IiwidmlkIjoiMiJ9',
#   'default_value': 'Disabled',
#   'current_value': 'Disabled',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__if-then-else',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19faWYtdGhlbi1lbHNlIiwidmlkIjoiMiJ9',
#   'default_value': 1,
#   'current_value': 1,
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__input_variable',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19faW5wdXRfdmFyaWFibGUiLCJ2aWQiOiIyIn0',
#   'default_value': 1,
#   'current_value': 1,
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__integer_constant',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19faW50ZWdlcl9jb25zdGFudCIsInZpZCI6IjIifQ',
#   'default_value': 'Disabled',
#   'current_value': 'Disabled',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__inverse_hyperbolic_cosine',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19faW52ZXJzZV9oeXBlcmJvbGljX2Nvc2luZSIsInZpZCI6IjIifQ',
#   'default_value': 'Disabled',
#   'current_value': 'Disabled',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__inverse_hyperbolic_sine',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19faW52ZXJzZV9oeXBlcmJvbGljX3NpbmUiLCJ2aWQiOiIyIn0',
#   'default_value': 'Disabled',
#   'current_value': 'Disabled',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__inverse_hyperbolic_tangent',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19faW52ZXJzZV9oeXBlcmJvbGljX3RhbmdlbnQiLCJ2aWQiOiIyIn0',
#   'default_value': 'Disabled',
#   'current_value': 'Disabled',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__less-than',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fbGVzcy10aGFuIiwidmlkIjoiMiJ9',
#   'default_value': 1,
#   'current_value': 1,
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__less-than-or-equal',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fbGVzcy10aGFuLW9yLWVxdWFsIiwidmlkIjoiMiJ9',
#   'default_value': 'Disabled',
#   'current_value': 'Disabled',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__logical_and',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fbG9naWNhbF9hbmQiLCJ2aWQiOiIyIn0',
#   'default_value': 'Disabled',
#   'current_value': 'Disabled',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__logical_not',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fbG9naWNhbF9ub3QiLCJ2aWQiOiIyIn0',
#   'default_value': 'Disabled',
#   'current_value': 'Disabled',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__logical_or',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fbG9naWNhbF9vciIsInZpZCI6IjIifQ',
#   'default_value': 'Disabled',
#   'current_value': 'Disabled',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__logical_xor',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fbG9naWNhbF94b3IiLCJ2aWQiOiIyIn0',
#   'default_value': 'Disabled',
#   'current_value': 'Disabled',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__logistic_function',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fbG9naXN0aWNfZnVuY3Rpb24iLCJ2aWQiOiIyIn0',
#   'default_value': 4,
#   'current_value': 4,
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__maximum',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fbWF4aW11bSIsInZpZCI6IjIifQ',
#   'default_value': 1,
#   'current_value': 1,
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__minimum',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fbWluaW11bSIsInZpZCI6IjIifQ',
#   'default_value': 1,
#   'current_value': 1,
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__modulo',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fbW9kdWxvIiwidmlkIjoiMiJ9',
#   'default_value': 'Disabled',
#   'current_value': 'Disabled',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__multiplication',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fbXVsdGlwbGljYXRpb24iLCJ2aWQiOiIyIn0',
#   'default_value': 0,
#   'current_value': 0,
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__natural_logarithm',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fbmF0dXJhbF9sb2dhcml0aG0iLCJ2aWQiOiIyIn0',
#   'default_value': 2,
#   'current_value': 2,
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__negation',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fbmVnYXRpb24iLCJ2aWQiOiIyIn0',
#   'default_value': 'Disabled',
#   'current_value': 'Disabled',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__power',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fcG93ZXIiLCJ2aWQiOiIyIn0',
#   'default_value': 'Disabled',
#   'current_value': 'Disabled',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__round',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fcm91bmQiLCJ2aWQiOiIyIn0',
#   'default_value': 'Disabled',
#   'current_value': 'Disabled',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__sign_function',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fc2lnbl9mdW5jdGlvbiIsInZpZCI6IjIifQ',
#   'default_value': 'Disabled',
#   'current_value': 'Disabled',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__sine',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fc2luZSIsInZpZCI6IjIifQ',
#   'default_value': 'Disabled',
#   'current_value': 'Disabled',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__square_root',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fc3F1YXJlX3Jvb3QiLCJ2aWQiOiIyIn0',
#   'default_value': 1,
#   'current_value': 1,
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__step_function',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fc3RlcF9mdW5jdGlvbiIsInZpZCI6IjIifQ',
#   'default_value': 2,
#   'current_value': 2,
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__subtraction',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fc3VidHJhY3Rpb24iLCJ2aWQiOiIyIn0',
#   'default_value': 0,
#   'current_value': 0,
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__tangent',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fdGFuZ2VudCIsInZpZCI6IjIifQ',
#   'default_value': 'Disabled',
#   'current_value': 'Disabled',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__two-argument_arctangent',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fdHdvLWFyZ3VtZW50X2FyY3RhbmdlbnQiLCJ2aWQiOiIyIn0',
#   'default_value': 'Disabled',
#   'current_value': 'Disabled',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'error_metric',
#   'parameter_id': 'eyJhcmciOiJlcnJvcl9tZXRyaWMiLCJ2aWQiOiIyIn0',
#   'default_value': 'Mean_Squared_Error',
#   'current_value': 'Mean_Squared_Error',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Mean_Absolute_Error',
#      'Mean_Absolute_Percentage_Error',
#      'Mean_Squared_Error',
#      'Root_Mean_Squared_Error',
#      'R^2_Goodness_of_Fit',
#      'Correlation_Coefficient',
#      'Maximum_Absolute_Error',
#      'Mean_Logarithm_Squared_Error',
#      'Median_Absolute_Error',
#      'Interquartile_Mean_Absolute_Error',
#      'AIC_Squared_Error',
#      'AIC_Absolute_Error',
#      'Rank_Correlation',
#      'Hinge_Loss_Error',
#      'Slope_Absolute_Error']}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'max_generations',
#   'parameter_id': 'eyJhcmciOiJtYXhfZ2VuZXJhdGlvbnMiLCJ2aWQiOiIyIn0',
#   'default_value': 3000,
#   'current_value': 3000,
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'int': {'min': 32,
#     'max': 10000000000000000,
#     'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'num_threads',
#   'parameter_id': 'eyJhcmciOiJudW1fdGhyZWFkcyIsInZpZCI6IjIifQ',
#   'default_value': 4,
#   'current_value': 4,
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'int': {'min': 0,
#     'max': 100000,
#     'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'prior_solutions',
#   'parameter_id': 'eyJhcmciOiJwcmlvcl9zb2x1dGlvbnMiLCJ2aWQiOiIyIn0',
#   'default_value': '',
#   'current_value': '',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'unicode': {}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'random_seed',
#   'parameter_id': 'eyJhcmciOiJyYW5kb21fc2VlZCIsInZpZCI6IjIifQ',
#   'default_value': 31337,
#   'current_value': 31337,
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'int': {'min': 0,
#     'max': 10000000000000000,
#     'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'split_mode',
#   'parameter_id': 'eyJhcmciOiJzcGxpdF9tb2RlIiwidmlkIjoiMiJ9',
#   'default_value': 1,
#   'current_value': 1,
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['custom', 1, 2]}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'sync_migrations',
#   'parameter_id': 'eyJhcmciOiJzeW5jX21pZ3JhdGlvbnMiLCJ2aWQiOiIyIn0',
#   'default_value': 'True',
#   'current_value': 'True',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['False', 'True']}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'target_expression_format',
#   'parameter_id': 'eyJhcmciOiJ0YXJnZXRfZXhwcmVzc2lvbl9mb3JtYXQiLCJ2aWQiOiIyIn0',
#   'default_value': 'None',
#   'current_value': 'None',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['None',
#      'exponential',
#      'feature_interaction']}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'target_expression_string',
#   'parameter_id': 'eyJhcmciOiJ0YXJnZXRfZXhwcmVzc2lvbl9zdHJpbmciLCJ2aWQiOiIyIn0',
#   'default_value': '',
#   'current_value': '',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'unicode': {}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'timeout_sec',
#   'parameter_id': 'eyJhcmciOiJ0aW1lb3V0X3NlYyIsInZpZCI6IjIifQ',
#   'default_value': 1000000,
#   'current_value': 1000000,
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'float': {'min': 0.0,
#     'max': 100000000.0,
#     'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'training_fraction',
#   'parameter_id': 'eyJhcmciOiJ0cmFpbmluZ19mcmFjdGlvbiIsInZpZCI6IjIifQ',
#   'default_value': 0.5,
#   'current_value': 0.5,
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'float': {'min': 0.0,
#     'max': 1.0,
#     'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'training_split_expr',
#   'parameter_id': 'eyJhcmciOiJ0cmFpbmluZ19zcGxpdF9leHByIiwidmlkIjoiMiJ9',
#   'default_value': '',
#   'current_value': '',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'unicode': {}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'validation_fraction',
#   'parameter_id': 'eyJhcmciOiJ2YWxpZGF0aW9uX2ZyYWN0aW9uIiwidmlkIjoiMiJ9',
#   'default_value': 0.5,
#   'current_value': 0.5,
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'float': {'min': 0.0,
#     'max': 1.0,
#     'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'validation_split_expr',
#   'parameter_id': 'eyJhcmciOiJ2YWxpZGF0aW9uX3NwbGl0X2V4cHIiLCJ2aWQiOiIyIn0',
#   'default_value': '',
#   'current_value': '',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'unicode': {}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'weight_expr',
#   'parameter_id': 'eyJhcmciOiJ3ZWlnaHRfZXhwciIsInZpZCI6IjIifQ',
#   'default_value': '',
#   'current_value': '',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'unicode': {}},
#   'vertex_id': '2',
#   'value': None}]

# %%
# looking specifically at the sin/cos operators and target expression, these are disabled by default
[
    param
    for param in tune.get_parameters()["tuning_parameters"]
    if param["parameter_name"].endswith("__sine")
    or param["parameter_name"].endswith("__cosine")
    or param["parameter_name"] == "target_expression_string"
]
# Out:
# [{'parameter_name': 'building_block__cosine',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fY29zaW5lIiwidmlkIjoiMiJ9',
#   'default_value': 'Disabled',
#   'current_value': 'Disabled',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'building_block__sine',
#   'parameter_id': 'eyJhcmciOiJidWlsZGluZ19ibG9ja19fc2luZSIsInZpZCI6IjIifQ',
#   'default_value': 'Disabled',
#   'current_value': 'Disabled',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'select': {'values': ['Disabled']},
#    'int': {'min': 0, 'max': 100, 'supports_grid_search': False}},
#   'vertex_id': '2',
#   'value': None},
#  {'parameter_name': 'target_expression_string',
#   'parameter_id': 'eyJhcmciOiJ0YXJnZXRfZXhwcmVzc2lvbl9zdHJpbmciLCJ2aWQiOiIyIn0',
#   'default_value': '',
#   'current_value': '',
#   'task_name': 'Eureqa Regressor (Default Search: 3000 Generations)',
#   'constraints': {'unicode': {}},
#   'vertex_id': '2',
#   'value': None}]

# %%
# First, disable all building blocks
print("Setting to disabled:")
for param in tune.get_parameters()["tuning_parameters"]:
    if (
        param["parameter_name"].startswith("building_block")
        and param["current_value"] != "Disabled"
    ):
        tune.set_parameter(parameter_name=param["parameter_name"], value="Disabled")
        print(param["parameter_name"], param["current_value"])

# Now, enable the specific building blocks that we know are relevant to this problem
# We know that the final expression should contain trigonometric functions and consist of the form f(x1, x2, v1, a1)
tune.set_parameter(parameter_name="building_block__sine", value=1)
tune.set_parameter(parameter_name="building_block__cosine", value=1)
tune.set_parameter(parameter_name="target_expression_string", value="f(x1, x2, v1, a1)")
tune.set_parameter(parameter_name="building_block__input_variable", value=1)
tune.set_parameter(parameter_name="building_block__constant", value=1)
tune.set_parameter(parameter_name="building_block__addition", value=1)
tune.set_parameter(parameter_name="building_block__subtraction", value=0)
tune.set_parameter(parameter_name="building_block__multiplication", value=0)

# now run this tuned eureqa model
tune.description = "Enabled sin/cos"
job = tune.run()

tuned_eq = job.get_result_when_complete()
job = tuned_eq.cross_validate()
job.wait_for_completion()
# Out:
# Setting to disabled:
# building_block__addition 0
# building_block__constant 0
# building_block__division 2
# building_block__if-then-else 1
# building_block__input_variable 1
# building_block__less-than 1
# building_block__logistic_function 4
# building_block__maximum 1
# building_block__minimum 1
# building_block__multiplication 0
# building_block__natural_logarithm 2
# building_block__square_root 1
# building_block__step_function 2
# building_block__subtraction 0

# %%
view_cv_scores(project_eureqa)
# Out:
#                                                model   cv_score
# 0  Eureqa Regressor (Default Search: 3000 Generat...   0.863400
# 2  Light Gradient Boosting on ElasticNet Predicti...   1.931188
# 1  Light Gradient Boosting on ElasticNet Predicti...   1.932670
# 3  Light Gradient Boosted Trees Regressor with Ea...   2.173850
# 4           eXtreme Gradient Boosted Trees Regressor   2.251016
# 5                             RandomForest Regressor   2.698264
# 8  Eureqa Regressor (Default Search: 3000 Generat...  14.649408

# %% [markdown]
# We can see a much better performance here by the Eureqa model!

# %% [markdown]
# # Compare DR result with physical equation

# %% [markdown]
# Remember that physicists have determined that the equation governing the motion of a double pendulum is:
#
# a2 = v1<sup>2</sup> * sin(x1 - x2) - a1 * cos(x2 - x1) - g * sin(x2)
#
# Where g is the gravitational constant – approximately 9.81 or 9.82 m/s.

# %%
# we can access the closed-form of the solution
pareto = tuned_eq.get_pareto_front()
solutions = pareto.solutions
best_solution = solutions[-1]
best_solution.expression
# Out:
# 'Target = 0.99845736281396*v1^2*sin(x1 - x2) - 9.86312521430275*sin(x2) - 0.999583191303474*a1*cos(x1 - x2)'

# %% [markdown]
# The Eureqa model has produced a coefficient on that last term of 9.86, remarkably close to the gravitational constant.
